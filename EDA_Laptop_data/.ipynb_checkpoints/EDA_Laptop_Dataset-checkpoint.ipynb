# %% [markdown]
# # Exploratory Data Analysis of Laptop Dataset
# **Author: Durvank Gade**

# %% [markdown]
# The Laptop dataset is an uncleaned dataset available at  https://www.kaggle.com/code/sreevaatsavbavana/laptop-price-prediction-and-eda/input . This dataset contains names, user ratings, prices(In Indian Rupees) and specifications of laptops available on Flipkart. This dataset is a **CSV(Comma Separated Values)** file. To read this file, I am going to use read_csv() function from pandas library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the Uncleaned dataset

filepath="Laptop_data_initial.csv" #Filepath of the Uncleaned dataset
df=pd.read_csv(filepath)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 98 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         984 non-null    int64
#  1   link                               984 non-null    object
#  2   name                               984 non-null    object
#  3   user rating                        690 non-null    float64
#  4   Price                              984 non-null    object
#  5   Sales Package                      984 non-null    object
#  6   Model Number                       984 non-null    object
#  7   Part Number                        984 non-null    object
#  8   Model Name                         709 non-null    object
#  9   Series                             787 non-null    object
#  10  Color                              984 non-null    object
#  11  Type                               984 non-null    object
#  12  Suitable For                       984 non-null    object
#  13  Power Supply                       548 non-null    object
#  14  Battery Cell                       680 non-null    object
#  15  MS Office Provided                 984 non-null    object
#  16  Dedicated Graphic Memory Type      338 non-null    object
#  17  Dedicated Graphic Memory Capacity  310 non-null    object
#  18  Processor Brand                    984 non-null    object
#  19  Processor Name                     984 non-null    object
#  20  Processor Generation               690 non-null    object
#  21  SSD                                984 non-null    object
#  22  SSD Capacity                       876 non-null    object
#  23  RAM                                984 non-null    object
#  24  RAM Type                           984 non-null    object
#  25  Processor Variant                  861 non-null    object
#  26  Clock Speed                        861 non-null    object
#  27  Expandable Memory                  383 non-null    object
#  28  Cache                              761 non-null    object
#  29  Graphic Processor                  964 non-null    object
#  30  Number of Cores                    724 non-null    float64
#  31  OS Architecture                    826 non-null    object
#  32  Operating System                   984 non-null    object
#  33  Supported Operating System         489 non-null    object
#  34  Mic In                             807 non-null    object
#  35  USB Port                           880 non-null    object
#  36  HDMI Port                          804 non-null    object
#  37  Touchscreen                        984 non-null    object
#  38  Screen Size                        984 non-null    object
#  39  Screen Resolution                  984 non-null    object
#  40  Screen Type                        883 non-null    object
#  41  Speakers                           852 non-null    object
#  42  Internal Mic                       843 non-null    object
#  43  Sound Properties                   698 non-null    object
#  44  Wireless LAN                       868 non-null    object
#  45  Bluetooth                          980 non-null    object
#  46  Dimensions                         863 non-null    object
#  47  Weight                             873 non-null    object
#  48  Disk Drive                         984 non-null    object
#  49  Finger Print Sensor                714 non-null    object
#  50  Keyboard                           883 non-null    object
#  51  Backlit Keyboard                   816 non-null    object
#  52  Additional Features                577 non-null    object
#  53  Warranty Summary                   984 non-null    object
#  54  Warranty Service Type              984 non-null    object
#  55  Covered in Warranty                984 non-null    object
#  56  Not Covered in Warranty            981 non-null    object
#  57  Domestic Warranty                  814 non-null    object
#  58  Ethernet                           310 non-null    object
#  59  Web Camera                         843 non-null    object
#  60  Pointer Device                     577 non-null    object
#  61  Included Software                  604 non-null    object
#  62  Battery Backup                     608 non-null    object
#  63  Chipset                            138 non-null    object
#  64  Memory Slots                       300 non-null    object
#  65  RAM Frequency                      393 non-null    object
#  66  RJ45                               418 non-null    object
#  67  Sound Chip                         111 non-null    object
#  68  Brightness                         12 non-null     object
#  69  Laptop Bag                         189 non-null    object
#  70  Other Accessories                  39 non-null     object
#  71  International Warranty             141 non-null    object
#  72  Wireless WAN                       62 non-null     object
#  73  Recovery Options                   32 non-null     object
#  74  RPM                                93 non-null     float64
#  75  Hardware Interface                 540 non-null    object
#  76  Face Recognition                   34 non-null     object
#  77  System Architecture                566 non-null    object
#  78  Refresh Rate                       157 non-null    object
#  79  Antivirus                          131 non-null    object
#  80  Multi Card Slot                    506 non-null    object
#  81  Lock Port                          224 non-null    object
#  82  NFC Support                        41 non-null     object
#  83  HDD Capacity                       182 non-null    object
#  84  Stylus Included                    51 non-null     object
#  85  TGP                                29 non-null     object
#  86  VGA Port                           91 non-null     object
#  87  Color Gamut                        4 non-null      object
#  88  Security Chip                      142 non-null    object
#  89  Inbuilt 4G LTE                     13 non-null     object
#  90  Cloud Storage                      1 non-null      object
#  91  S-video                            16 non-null     object
#  92  Dock Port                          33 non-null     object
#  93  Firewire Port                      34 non-null     object
#  94  RJ11                               41 non-null     object
#  95  Read/Write Speed                   4 non-null      object
#  96  EMMC Storage Capacity              24 non-null     object
#  97  Optane Memory                      6 non-null      object
# dtypes: float64(3), int64(1), object(94)
# memory usage: 753.5+ KB

# %%
pd.options.display.max_columns=98
df.head(3)
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://www.flipkart.com/asus-rog-strix-scar-1...
# 1           1  https://www.flipkart.com/asus-rog-strix-scar-1...
# 2           2  https://www.flipkart.com/hp-victus-ryzen-7-oct...
#
#                                                 name  user rating      Price  \
# 0  ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 ...          5.0  ?2,34,990
# 1  ASUS ROG Strix SCAR 15 Core i9 12th Gen - (32 ...          NaN  ?2,29,990
# 2  HP Victus Ryzen 7 Octa Core 5800H - (16 GB/512...          NaN  ?1,04,091
#
#                                        Sales Package    Model Number  \
# 0  Laptop, Power Adaptor, User Guide, Warranty Do...  G733ZW-LL139WS
# 1  Laptop, Power Adaptor, User Guide, Warranty Do...  G533ZW-LN136WS
# 2  Laptop, battery, adapter, cables and user manuals      16-e0351AX
#
#        Part Number      Model Name             Series        Color  \
# 0  90NR08G2-M007S0  G733ZW-LL139WS  ROG Strix SCAR 17    Off Black
# 1  90NR0872-M007L0  G533ZW-LN136WS  ROG Strix SCAR 15    Off Black
# 2      552X1PA#ACJ      16-e0351AX             Victus  Mica Silver
#
#             Type Suitable For      Power Supply Battery Cell  \
# 0  Gaming Laptop       Gaming  280 W AC Adapter       4 cell
# 1  Gaming Laptop       Gaming  280 W AC Adapter       4 cell
# 2  Gaming Laptop       Gaming               NaN       4 cell
#
#   MS Office Provided Dedicated Graphic Memory Type  \
# 0                Yes                         GDDR6
# 1                Yes                         GDDR6
# 2                Yes                         GDDR6
#
#   Dedicated Graphic Memory Capacity Processor Brand     Processor Name  \
# 0                              8 GB           Intel            Core i9
# 1                              8 GB           Intel            Core i9
# 2                              4 GB             AMD  Ryzen 7 Octa Core
#
#   Processor Generation  SSD SSD Capacity    RAM RAM Type Processor Variant  \
# 0             12th Gen  Yes         1 TB  32 GB     DDR5            12900H
# 1             12th Gen  Yes         1 TB  32 GB     DDR5            12900H
# 2                  NaN  Yes       512 GB  16 GB     DDR4             5800H
#
#                                    Clock Speed Expandable Memory Cache  \
# 0  2.5 GHz upto max turbo frequency at 5.0 Ghz                64    24
# 1  2.5 GHz upto max turbo frequency at 5.0 Ghz                64    24
# 2  3.2 GHz upto max turbo frequency at 4.4 GHz               NaN  16MB
#
#             Graphic Processor  Number of Cores OS Architecture  \
# 0  NVIDIA GeForce RTX 3070 Ti             14.0          64 bit
# 1  NVIDIA GeForce RTX 3070 Ti             14.0          64 bit
# 2     NVIDIA GeForce RTX 3050              8.0          64 bit
#
#   Operating System               Supported Operating System Mic In  \
# 0  Windows 11 Home                          Windows 11 Home    Yes
# 1  Windows 11 Home                          Windows 11 Home    Yes
# 2  Windows 11 Home  Windows 11 Home 64 Plus Single Language    Yes
#
#                                             USB Port     HDMI Port  \
# 0  1 x Thunderbolt 4 support DisplayPort, 1 x USB...  1 x HDMI 2.1
# 1  1 x Thunderbolt 4 support DisplayPort, 1 x USB...  1 x HDMI 2.1
# 2  1 x SuperSpeed USB Type-C 5Gbps signaling rate...   1x HDMI 2.0
#
#   Touchscreen           Screen Size  Screen Resolution  \
# 0          No  43.94 cm (17.3 inch)  2560 x 1440 Pixel
# 1          No  39.62 cm (15.6 inch)  2560 x 1440 Pixel
# 2          No  40.89 cm (16.1 inch)  1920 x 1080 PIxel
#
#                                          Screen Type                Speakers  \
# 0  WQHD, IPS-level, 300nits, Contras 1000:1, Anti...  Four built-in speakers
# 1  WQHD, IPS-level, 300nits, Contras 1000:1, Anti...  Four built-in speakers
# 2  Full HD, 144 Hz, 7 ms response time, IPS, micr...  Built-in Dual Speakers
#
#                               Internal Mic  \
# 0                Built-in array microphone
# 1                Built-in array microphone
# 2  Built-in dual array digital microphones
#
#                                     Sound Properties           Wireless LAN  \
# 0  AI noise-canceling technology, Dolby Atmos, Hi...     Wi-Fi 6E(802.11ax)
# 1  AI noise-canceling technology, Dolby Atmos, Hi...     Wi-Fi 6E(802.11ax)
# 2                                       Audio by B&O  Realtek Wi-Fi 6 (2x2)
#
#   Bluetooth           Dimensions   Weight     Disk Drive Finger Print Sensor  \
# 0      v5.2  395 x 282 x 28.3 mm  2.90 kg  Not Available                  No
# 1      v5.2  354 x 259 x 27.2 mm  2.30 kg  Not Available                  No
# 2      v5.2  370 x 262 x 23.5 mm  2.48 kg  Not Available                  No
#
#                                             Keyboard Backlit Keyboard  \
# 0               Backlit Chiclet Keyboard Per-Key RGB              Yes
# 1               Backlit Chiclet Keyboard Per-Key RGB              Yes
# 2  Full-size, backlit, mica silver keyboard with ...              Yes
#
#       Additional Features        Warranty Summary Warranty Service Type  \
# 0  90 WHrs Li-ion Battery  1 Year Onsite Warranty                Onsite
# 1  90 WHrs Li-ion Battery  1 Year Onsite Warranty                Onsite
# 2    70 Wh Li-ion polymer  1 Year Onsite Warranty                Onsite
#
#      Covered in Warranty Not Covered in Warranty Domestic Warranty  \
# 0  Manufacturing Defects       Accidental Damage            1 Year
# 1  Manufacturing Defects       Accidental Damage            1 Year
# 2  Manufacturing Defects         Physical Damage            1 Year
#
#               Ethernet                     Web Camera  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2  10/100/1000 GbE LAN  HP Wide Vision 720p HD camera
#
#                                  Pointer Device  \
# 0                                           NaN
# 1                                           NaN
# 2  HP Imagepad with multi-touch gesture support
#
#                                    Included Software Battery Backup Chipset  \
# 0                                                NaN            NaN     NaN
# 1                                                NaN            NaN     NaN
# 2  Microsoft Home & Student 2019, HP Documentatio...            NaN     NaN
#
#   Memory Slots RAM Frequency RJ45 Sound Chip Brightness Laptop Bag  \
# 0          NaN           NaN  NaN        NaN        NaN        NaN
# 1          NaN           NaN  NaN        NaN        NaN        NaN
# 2          NaN           NaN  NaN        NaN        NaN        NaN
#
#   Other Accessories International Warranty Wireless WAN Recovery Options  RPM  \
# 0               NaN                    NaN          NaN              NaN  NaN
# 1               NaN                    NaN          NaN              NaN  NaN
# 2               NaN                    NaN          NaN              NaN  NaN
#
#   Hardware Interface Face Recognition System Architecture Refresh Rate  \
# 0                NaN              NaN                 NaN          NaN
# 1                NaN              NaN                 NaN          NaN
# 2                NaN              NaN                 NaN          NaN
#
#   Antivirus Multi Card Slot Lock Port NFC Support HDD Capacity  \
# 0       NaN             NaN       NaN         NaN          NaN
# 1       NaN             NaN       NaN         NaN          NaN
# 2       NaN             NaN       NaN         NaN          NaN
#
#   Stylus Included  TGP VGA Port Color Gamut Security Chip Inbuilt 4G LTE  \
# 0             NaN  NaN      NaN         NaN           NaN            NaN
# 1             NaN  NaN      NaN         NaN           NaN            NaN
# 2             NaN  NaN      NaN         NaN           NaN            NaN
#
#   Cloud Storage S-video Dock Port Firewire Port RJ11 Read/Write Speed  \
# 0           NaN     NaN       NaN           NaN  NaN              NaN
# 1           NaN     NaN       NaN           NaN  NaN              NaN
# 2           NaN     NaN       NaN           NaN  NaN              NaN
#
#   EMMC Storage Capacity Optane Memory
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN

# %% [markdown]
# There are 984 rows and 98 columns in the original dataset. To remove unwanted rows, a new DataFrame that contains only required columns from the original datasets can be created. The rows containing null values were removed using using **dropna()** function.

# %%
df1=df[["name","Model Number","user rating","Price","Processor Brand","Processor Name","SSD","RAM","Processor Variant"]].copy()
df1.dropna(inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#      index                                               name  \
# 0        0  ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 ...
# 1        8  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/1...
# 2        9  DELL Inspiron Pentium Silver - (8 GB/256 GB SS...
# 3       10  DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...
# 4       18  realme Book Prime Core i5 11th Gen - (16 GB/51...
# ..     ...                                                ...
# 631    976  ASUS VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 632    977  Lenovo Yoga Core i7 10th Gen - (16 GB/1 TB SSD...
# 633    979  Nokia PureBook X14 Core i5 10th Gen - (8 GB/51...
# 634    982  HP 14a Celeron Dual Core - (4 GB/64 GB EMMC St...
# 635    983  Lenovo Core i3 10th Gen - (4 GB/1 TB HDD/Windo...
#
#         Model Number  user rating      Price Processor Brand  \
# 0     G733ZW-LL139WS          5.0  ?2,34,990           Intel
# 1     FX506LH-HN310W          4.7    ?64,990           Intel
# 2      Inspiron 3521          4.0    ?32,999           Intel
# 3      Inspiron 3525          4.2    ?30,990             AMD
# 4        CloudPro002          4.3    ?64,990           Intel
# ..               ...          ...        ...             ...
# 631    X412FA-EK296T          4.5    ?53,690           Intel
# 632  Yoga S940-14IIL          2.5  ?1,42,990           Intel
# 633      NKi510UL85S          4.4    ?53,990           Intel
# 634    14a- na0002TU          3.6    ?26,990           Intel
# 635              V14          3.1    ?44,590           Intel
#
#         Processor Name  SSD    RAM Processor Variant
# 0              Core i9  Yes  32 GB            12900H
# 1              Core i5  Yes   8 GB         i5-10300H
# 2       Pentium Silver  Yes   8 GB             N5030
# 3     Athlon Dual Core  Yes   8 GB             3050U
# 4              Core i5  Yes  16 GB            11320H
# ..                 ...  ...    ...               ...
# 631            Core i5  Yes   8 GB             8265U
# 632            Core i7  Yes  16 GB            1065G7
# 633            Core i5  Yes   8 GB            10210U
# 634  Celeron Dual Core   No   4 GB             N4020
# 635            Core i3   No   4 GB            1035G1
#
# [636 rows x 10 columns]

# %% [markdown]
# The “user rating” column contains the ratings given by the customers for each laptop, ranging from 0 to 5. To ensure that there are no invalid values in this column, we can use a for loop to iterate over the ratings and check if any of them are greater than 5. After running the code, we find that there are no such values, so we do not need to perform any further cleaning on this column.
# The “price” column shows the price of each laptop in Indian Rupees (INR). However, some of the values have ‘?’ and ‘,’ symbols, which make them difficult to process as numerical data. To remove these symbols and convert the values into integers, we can use the following code:

# %%
for i in df1["user rating"]:
    if i>5:
        print("Invalid value")
    else:
        continue
l=[]
price_split=[]
processed_inr=''
Processed_Price=pd.DataFrame()
for i in range(0, len(df1['Price'])):
    price_split=df1["Price"][i].split(sep=',')
    price_split[0]=price_split[0].split(sep='?')[1]
    for j in price_split:
        processed_inr+=j
    df1.loc[i,"Price"]=int(processed_inr)
    processed_inr=''
df1
# Out:
#      index                                               name  \
# 0        0  ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 ...
# 1        8  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/1...
# 2        9  DELL Inspiron Pentium Silver - (8 GB/256 GB SS...
# 3       10  DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...
# 4       18  realme Book Prime Core i5 11th Gen - (16 GB/51...
# ..     ...                                                ...
# 631    976  ASUS VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 632    977  Lenovo Yoga Core i7 10th Gen - (16 GB/1 TB SSD...
# 633    979  Nokia PureBook X14 Core i5 10th Gen - (8 GB/51...
# 634    982  HP 14a Celeron Dual Core - (4 GB/64 GB EMMC St...
# 635    983  Lenovo Core i3 10th Gen - (4 GB/1 TB HDD/Windo...
#
#         Model Number  user rating   Price Processor Brand     Processor Name  \
# 0     G733ZW-LL139WS          5.0  234990           Intel            Core i9
# 1     FX506LH-HN310W          4.7   64990           Intel            Core i5
# 2      Inspiron 3521          4.0   32999           Intel     Pentium Silver
# 3      Inspiron 3525          4.2   30990             AMD   Athlon Dual Core
# 4        CloudPro002          4.3   64990           Intel            Core i5
# ..               ...          ...     ...             ...                ...
# 631    X412FA-EK296T          4.5   53690           Intel            Core i5
# 632  Yoga S940-14IIL          2.5  142990           Intel            Core i7
# 633      NKi510UL85S          4.4   53990           Intel            Core i5
# 634    14a- na0002TU          3.6   26990           Intel  Celeron Dual Core
# 635              V14          3.1   44590           Intel            Core i3
#
#      SSD    RAM Processor Variant
# 0    Yes  32 GB            12900H
# 1    Yes   8 GB         i5-10300H
# 2    Yes   8 GB             N5030
# 3    Yes   8 GB             3050U
# 4    Yes  16 GB            11320H
# ..   ...    ...               ...
# 631  Yes   8 GB             8265U
# 632  Yes  16 GB            1065G7
# 633  Yes   8 GB            10210U
# 634   No   4 GB             N4020
# 635   No   4 GB            1035G1
#
# [636 rows x 10 columns]

# %% [markdown]
# The cleaned data provides many useful insights, such as price trends, user preferences, feature correlations, and market opportunities. For example, we can:
# Examine the most common specifications of laptops and compare them with the average prices and ratings.
# Identify potential gaps or opportunities in the market based on the demand and supply of different laptop features.
# Investigate whether there is a relationship between the processor brand and the user ratings of laptops.
# This can be achieved through graphical visualisation of data using Python libraries like matplotlib, seaborn, etSome of the plots possible are:c.

# %% [markdown]
# **1. Histogram of distribution of User Ratings:**

# %%
sns.histplot(df1['user rating'], bins=10, kde=True)
plt.title('Distribution of User Ratings')
plt.xlabel('User Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **2. Scatter Plot of RAM vs Price:**

# %%
sns.scatterplot(x='RAM', y='Price', data=df1)
plt.title('RAM vs Price Scatter Plot')
plt.xlabel('RAM Capacity (in GB)')
plt.ylabel('Price (INR)')
plt.show()

# %% [markdown]
# From the above scatterplot we can infer that most of the 4GB RAM laptops are below 50,000 INR price range and all the 32 GB RAM laptops are above 1,00,000 INR price range.

# %% [markdown]
# **3.User Ratings vs Processor Brands**

# %%
sns.barplot(x='Processor Brand', y='user rating', data=df1)
plt.figure(figsize=(12, 6))
plt.title('Average User Ratings by Processor Brand')
plt.xlabel('Processor Brand')
plt.ylabel('Average User Rating')
plt.show()
